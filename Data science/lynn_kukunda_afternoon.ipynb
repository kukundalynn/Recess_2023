# %% [markdown]
# # Afternoon assignment

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# no.1

# %%
x = pd.Series([4,65,436,3,9])
y = pd.Series([7,0,3,897,9])

print("Original Series:")
print(x)
print("Second group:")
print(y)

print("\nCompare the elements of the said Series:")
print(x == y)
# Out:
# Original Series:
# 0      4
# 1     65
# 2    436
# 3      3
# 4      9
# dtype: int64
# Second group:
# 0      7
# 1      0
# 2      3
# 3    897
# 4      9
# dtype: int64
#
# Compare the elements of the said Series:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# n0.2

# %%
s1 = pd.Series([2,4,6,8,14])
s2 = pd.Series([1,3,5,7,9])

print(s1)
print(s2)

print("\nAdd :")
print(s1 + s2)

print("\nSubtract :")
print(s1 - s2)

print("\nMultiply:")
print(s1 * s2)

print("\nDivide :")
print(s1 / s2)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    14
# dtype: int64
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64
#
# Add :
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
#
# Subtract :
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
#
# Multiply:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
#
# Divide :
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %% [markdown]
# no.3

# %%
dictionary1 = {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}
s = pd.Series(dictionary1)
print(dictionary1)
print(s)
# Out:
# {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %% [markdown]
# no.4

# %%
b = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])
print(b)
a = np.array(b)
print(a)
# Out:
# 0     Love
# 1      800
# 2      Joy
# 3    789.9
# 4    Peace
# 5     True
# dtype: object
# ['Love' 800 'Joy' 789.9 'Peace' True]

# %% [markdown]
# no.5

# %%
df = pd.read_csv('AfricaCupofNationsMatches.csv')
mod= df['HomeTeamGoals'].mode()[0]

df['HomeTeamGoals'] = df['HomeTeamGoals'].apply(lambda x: mod if x == mod else 'Other')
print("\nSeries with most frequent value and 'Other':")
print(df['HomeTeamGoals'])
# Out:
# Series with most frequent value and 'Other':
# 0        1.0
# 1      Other
# 2      Other
# 3      Other
# 4        1.0
#        ...
# 617    Other
# 618      1.0
# 619    Other
# 620    Other
# 621    Other
# Name: HomeTeamGoals, Length: 622, dtype: object

# %% [markdown]
# # Part 2
# no.1

# %%
df = pd.read_csv('AfricaCupofNationsMatches.csv')

# %% [markdown]
# no.2

# %%
df.head(7)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %% [markdown]
# no.3

# %%
df[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']]
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %% [markdown]
# no.4

# %%
df[df['HomeTeam'] == 'Egypt']
# Out:
#     Year      Date  Time  HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959  22-May-59   NaN    Egypt   Ethiopia            4.0            0.0
# 5   1959  29-May-59   NaN    Egypt      Sudan            2.0            1.0
# 7   1962  18-Jan-62   NaN    Egypt     Uganda            2.0            1.0
# 13  1963  24-Nov-63   NaN    Egypt    Nigeria            6.0            3.0
# 14  1963  26-Nov-63   NaN    Egypt      Sudan            2.0            2.0
# 16  1963  30-Nov-63   NaN    Egypt   Ethiopia            3.0            0.0
#
#                 Stage SpecialWinConditions                 Stadium  \
# 3    Final Tournament                  NaN   Prince Farouk Stadium
# 5    Final Tournament                  NaN   Prince Farouk Stadium
# 7          Semifinals                  NaN  Hailé Sélassié Stadium
# 13            Group B                  NaN   Kumasi Sports Stadium
# 14            Group B                  NaN   Kumasi Sports Stadium
# ...

# %% [markdown]
# no.5

# %%
df.shape
# Out:
# (622, 12)

# %% [raw]
# no.6

# %%
df[df['Attendance'].isna()]
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %% [raw]
# no.7

# %%
df[df['HomeTeamGoals'].between(3, 6)]
# Out:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
#      HomeTeamGoals  AwayTeamGoals              Stage    SpecialWinConditions  \
# ...

# %% [markdown]
# no.8

# %%
df.at[2, 'AwayTeamGoals'] = 10

# %% [markdown]
# no.9

# %%
df.sort_values(by=['HomeTeam', 'HomeTeamGoals'], ascending=[True, False])
# Out:
#      Year                         Date           Time    HomeTeam  \
# 205  1990                      2-Mar-90            NaN   Algeria
# 29   1968                     14-Jan-68            NaN   Algeria
# 135  1980                     16-Mar-80            NaN   Algeria
# 164  1984                      5-Mar-84            NaN   Algeria
# 171  1984                     17-Mar-84            NaN   Algeria
# ..    ...                           ...            ...        ...
# 521  2012                     12-Feb-12  20:30[note 1]    Zambia
# 549  2017  23 January 2017 (2017-01-23)          20:00  Zimbabwe
# 398  2004                     25-Jan-04          16:30  Zimbabwe
# 437  2006                     23-Jan-06          20:00  Zimbabwe
# 575  2019     30 June 2019 (2019-06-30)          21:00  Zimbabwe
#
#          AwayTeam  HomeTeamGoals  AwayTeamGoals              Stage  \
# 205       Nigeria            5.0            1.0            Group A
# ...

# %% [markdown]
# no.10

# %%
df.columns.values.tolist()
# Out:
# ['Year',
#  'Date ',
#  'Time ',
#  'HomeTeam',
#  'AwayTeam',
#  'HomeTeamGoals',
#  'AwayTeamGoals',
#  'Stage',
#  'SpecialWinConditions',
#  'Stadium',
#  'City',
#  'Attendance']

# %% [markdown]
# no.11

# %%
df.insert(loc=9, column='DayWeather', value='sunny')

# %% [markdown]
# no.12

# %%
new_rows = pd.DataFrame({'column1': [1, 2], 'column2': [3, 4]})
df = pd.concat([df, new_rows])

# %% [markdown]
# no.13

# %%
df['AwayTeam'].replace('Uganda', 'China')
# Out:
# 0              Egypt
# 1       South Africa
# 2           Ethiopia
# 3           Ethiopia
# 4           Ethiopia
#            ...
# 619          Nigeria
# 620          Nigeria
# 621          Algeria
# 0                NaN
# 1                NaN
# Name: AwayTeam, Length: 624, dtype: object

# %% [markdown]
# no.14

# %%
df.reset_index(drop=True)
# Out:
#        Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957.0                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957.0                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959.0                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959.0                  25-May-59    NaN     Sudan        Ethiopia
# ..      ...                        ...    ...        ...            ...
# 619  2019.0  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019.0  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019.0  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622     NaN                        NaN    NaN        NaN            NaN
# 623     NaN                        NaN    NaN        NaN            NaN
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# no.15

# %%
if 'Stadium' in df.columns:
    print("The 'Stadium' column is present in the DataFrame.")
else:
    print("The 'Stadium' column is not present in the DataFrame.")
# Out:
# The 'Stadium' column is present in the DataFrame.

# %% [markdown]
# no.16

# %%
df['AwayTeamGoals'].astype(float)
# Out:
# 0       2.0
# 1       NaN
# 2      10.0
# 3       0.0
# 4       0.0
#        ...
# 619     1.0
# 620     1.0
# 621     1.0
# 0       NaN
# 1       NaN
# Name: AwayTeamGoals, Length: 624, dtype: float64

# %% [markdown]
# no.17

# %%
df.drop(df.tail(10).index,inplace=True)

# %% [markdown]
# no.18

# %%
for index, row in df.iterrows():
    print(row['AwayTeam'], row['AwayTeamGoals'])
# Out:
#  Ethiopia 10.0
#  Ethiopia 0.0
#  Ethiopia 0.0
#  Sudan 1.0
#  Tunisia 2.0
#  Uganda 1.0
#  Uganda 0.0
# Egypt 2.0
#  Tunisia 1.0
#  Ethiopia 0.0
#  Tunisia 2.0
#  Nigeria 3.0
#  Sudan 2.0
#  Nigeria 0.0
#  Ethiopia 0.0
#  Sudan 0.0
#  Ethiopia 0.0
#  Tunisia 0.0
#  Ethiopia 1.0
#  Congo-Léopoldville 2.0
#  Congo-Léopoldville 0.0
#  Ivory Coast 1.0
#  Ivory Coast 1.0
#  Tunisia 2.0
#  Uganda 1.0
#  Algeria 0.0
#  Ivory Coast 0.0
#  Uganda 0.0
#  Uganda 1.0
#  Algeria 1.0
#  Senegal 2.0
#  Congo-Brazzaville 0.0
#  Congo-Brazzaville 1.0
#  Congo-Kinshasa 1.0
#  Senegal 1.0
#  Congo-Brazzaville 1.0
#  Congo-Kinshasa 3.0
#  Ivory Coast 3.0
#  Ethiopia 0.0
#  Ghana 0.0
#  Ivory Coast 2.0
#  Ethiopia 0.0
#  Ethiopia 2.0
#  Sudan 0.0
#  Ethiopia 1.0
#  Cameroon 1.0
#  Congo-Kinshasa 0.0
#  Guinea 1.0
#  Guinea 2.0
#  Ghana 1.0
#  Ghana 1.0
#  Congo-Kinshasa 0.0
#  Ghana 2.0
#  Sudan 2.0
#  Ivory Coast 1.0
#  Ghana 0.0
#  Kenya 1.0
#  Togo 3.0
#  Kenya 1.0
#  Togo 0.0
#  Kenya 1.0
# ...

# %% [raw]
# no.19

# %%
#new_order = ['Date', 'Year', 'Time']
df.iloc[:, [1, 0, 2]]
# Out:
#                         Date     Year  Time
# 2                   16-Feb-57  1957.0    NaN
# 3                   22-May-59  1959.0    NaN
# 4                   25-May-59  1959.0    NaN
# 5                   29-May-59  1959.0    NaN
# 6                   14-Jan-62  1962.0    NaN
# ..                        ...     ...    ...
# 609  6 July 2019 (2019-07-06)  2019.0  21:00
# 610  7 July 2019 (2019-07-07)  2019.0  18:00
# 611  7 July 2019 (2019-07-07)  2019.0  21:00
# 612  8 July 2019 (2019-07-08)  2019.0  18:00
# 613  8 July 2019 (2019-07-08)  2019.0  21:00
#
# [612 rows x 3 columns]

# %% [markdown]
# no.20

# %%
df = df[df.HomeTeamGoals != 0]
print("\nDataFrame after deleting rows with HomeTeamGoals value of 0:")
print(df)
# Out:
# DataFrame after deleting rows with HomeTeamGoals value of 0:
#        Year                     Date   Time      HomeTeam   AwayTeam  \
# 2    1957.0                 16-Feb-57    NaN       Egypt    Ethiopia
# 3    1959.0                 22-May-59    NaN        Egypt   Ethiopia
# 4    1959.0                 25-May-59    NaN       Sudan    Ethiopia
# 5    1959.0                 29-May-59    NaN        Egypt      Sudan
# 6    1962.0                 14-Jan-62    NaN    Ethiopia     Tunisia
# ..      ...                       ...    ...          ...        ...
# 606  2019.0  5 July 2019 (2019-07-05)  18:00     Morocco       Benin
# 608  2019.0  6 July 2019 (2019-07-06)  18:00     Nigeria    Cameroon
# 610  2019.0  7 July 2019 (2019-07-07)  18:00  Madagascar    DR Congo
# 611  2019.0  7 July 2019 (2019-07-07)  21:00     Algeria      Guinea
# 613  2019.0  8 July 2019 (2019-07-08)  21:00       Ghana     Tunisia
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# ...
